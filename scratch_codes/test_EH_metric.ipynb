from desdeo_emo.othertools.EH_metric import Expanding_HC
import numpy as np
import matplotlib.pyplot as plt
ref = np.array([-0.2,1.2])
#a= np.array([[2,2],[3,2],[2,3]])
#b= np.array([[2,2],[3,2],[2,3],[1,5]])
c=np.array([[ 0.86710457,  0.36245303],
 [-0.1889622 ,  1.2933434 ],
 [ 1.12195353, -0.10492351],
 [ 0.06283107,  1.14031466],
 [ 1.10246369, -0.06992459],
 [ 0.14317406,  1.10096707],
 [ 1.04651473,  0.03984029],
 [ 1.1698649 , -0.17258715],
 [ 1.02878582,  0.07826906],
 [ 0.21866681,  1.03627122],
 [-0.12093954,  1.24750603],
 [ 0.65098612,  0.65879058],
 [ 0.33876655,  0.9468047 ],
 [ 0.68701597,  0.61881467],
 [ 0.94628554,  0.23911485],
 [ 0.89725268,  0.32215765],
 [ 0.41984546,  0.88188182],
 [ 0.29976348,  0.97927014],
 [ 0.54319051,  0.78117302],
 [ 0.78264611,  0.49120614],
 [-0.05021103,  1.20620581],
 [ 1.21206347, -0.23885766],
 [ 1.06600339,  0.00263263],
 [ 0.85063743,  0.41139027],
 [ 0.91785951,  0.27912023],
 [-0.013694  ,  1.18373625],
 [ 0.99620991,  0.15953516],
 [ 0.96891176,  0.19797628],
 [ 0.50327123,  0.8171285 ],
 [ 0.37917524,  0.91431565],
 [ 0.25751102,  1.00571991],
 [-0.22286388,  1.30839   ],
 [ 0.81756319,  0.45169274],
 [ 1.00833019,  0.11708305],
 [ 0.619587  ,  0.70393867],
 [ 0.57849346,  0.73947186],
 [ 0.72409193,  0.5796776 ],
 [-0.31958915,  1.3641027 ],
 [ 0.18071273,  1.06841902],
 [-0.155088  ,  1.27532635],
 [-0.2881679 ,  1.34729923],
 [ 1.09028554, -0.03313625],
 [ 0.10017124,  1.11497744],
 [ 0.02438991,  1.1643511 ],
 [ 1.13715824, -0.13955422],
 [-0.25596532,  1.32903314],
 [-0.0831914 ,  1.24179808],
 [ 1.17274303, -0.20642039],
 [ 0.7534073 ,  0.53481077],
 [ 0.45963141,  0.84784536]])
sc = c[c[:,0].argsort()]
sc1 = sc[0:10,:]
sc2 = sc[20:25,:]
sc3 = sc[35:45,:]
n_obj = 2
z=Expanding_HC()
a=np.max(sc, axis=0)
set_sizes1 = z.hypercube_size(ref,sc1,n_obj,a)
set_sizes2 = z.hypercube_size(ref,sc2,n_obj,a)
set_sizes3 = z.hypercube_size(ref,sc3,n_obj,a)
print(set_sizes1)
print(set_sizes2)
print(set_sizes3)
set_sizes_all = {'1':set_sizes1,'2':set_sizes2,'3':set_sizes3}
# Out:
# [array([0.05522044, 0.06522799, 0.06842843, 0.07945883, 0.09459195,
#        0.09637169, 0.10798251, 0.12030084, 0.12358179, 0.15370977])]
# [array([0.51139687, 0.54422184, 0.58022641, 0.61316138, 0.6422877 ])]
# [array([0.92227803, 0.94573062, 0.96439814, 0.98692019, 0.9969199 ,
#        1.0137966 , 1.02842364, 1.04450255, 1.06453628, 1.07458373])]

# %%
for key in set_sizes_all:
    s_sizes = set_sizes_all[key]
    #print(s_sizes[0])
    #print(np.shape(s_sizes)[1])
print(z.area(set_sizes_all))
plt.scatter(sc1[:,0], sc1[:,1])
plt.scatter(sc2[:,0], sc2[:,1])
plt.scatter(sc3[:,0], sc3[:,1])
plt.scatter(ref[0], ref[1])
plt.show()
# Out:
# [0.9780963119982408, 0.496324896253164, 0.07037476511027918]

# %%
from desdeo_emo.othertools.ProbabilityWrong import Probability_wrong
unc = np.array([[0.08927262, 0.08923547],
                [0.08125746, 0.0812235 ],
                [0.07903736, 0.07900394],
                [0.08216664, 0.08213209],
                [0.08985331, 0.08981566],
                [0.08044531, 0.08041143],
                [0.08021955, 0.08018568],
                [0.08392857, 0.08389341],
                [0.08606064, 0.08602464],
                [0.08779036, 0.08775366],
                [0.09294083, 0.09290217],
                [0.08161855, 0.08158421],
                [0.07862908, 0.07859578],
                [0.07841768, 0.07838443],
                [0.07907833, 0.0790448 ],
                [0.07634756, 0.07631525],
                [0.09499277, 0.09495343],
                [0.0780976 , 0.07806473],
                [0.09730448, 0.09726419],
                [0.07907625, 0.07904305],
                [0.09067502, 0.09063736],
                [0.08232178, 0.08228722],
                [0.07977149, 0.07973776],
                [0.08642078, 0.08638463],
                [0.08715832, 0.08712185],
                [0.07818454, 0.07815145],
                [0.08627649, 0.08624045],
                [0.07921577, 0.07918221],
                [0.09014795, 0.0901104 ],
                [0.08009131, 0.08005755],
                [0.09036436, 0.09032666],
                [0.08185068, 0.08181623],
                [0.08435838, 0.08432301],
                [0.07976466, 0.07973106],
                [0.08289803, 0.0828633 ],
                [0.08330096, 0.083266  ],
                [0.07931052, 0.07927709],
                [0.07967747, 0.0796438 ],
                [0.08014344, 0.08010959],
                [0.08231218, 0.08227776],
                [0.08097382, 0.08093973],
                [0.0857062 , 0.08567047],
                [0.07915617, 0.0791227 ],
                [0.07898188, 0.07894846],
                [0.08265359, 0.08261895],
                [0.0876221 , 0.08758563],
                [0.07870303, 0.0786698 ],
                [0.0782269 , 0.07819376],
                [0.08194172, 0.08190732],
                [0.08451514, 0.08447973]])
sunc = unc[c[:,0].argsort()]
sunc[35:45,:] = sunc[35:45,:] * 10
pwrong = Probability_wrong(mean_values=sc, stddev_values=sunc, n_samples=1000)
pwrong.vect_sample_f()

# %%
sc_samples = pwrong.f_samples
sc1 = sc_samples[0:10,:,:]
sc2 = sc_samples[20:25,:,:]
sc3 = sc_samples[35:45,:,:]
n_obj = 2
sc1_samples = sc1.transpose(2,0,1).reshape(10000,2)
sc2_samples = sc2.transpose(2,0,1).reshape(1000*5,2)
sc3_samples = sc3.transpose(2,0,1).reshape(10000,2)
sc_samples_all = sc_samples.transpose(2,0,1).reshape(50000,2)
z=Expanding_HC()
a=np.max(sc_samples_all, axis=0)
set_sizes1 = z.hypercube_size(ref,sc1_samples,n_obj,a)
set_sizes2 = z.hypercube_size(ref,sc2_samples,n_obj,a)
set_sizes3 = z.hypercube_size(ref,sc3_samples,n_obj,a)
print(set_sizes1)
print(set_sizes2)
print(set_sizes3)
set_sizes_all = {'1':set_sizes1,'2':set_sizes2,'3':set_sizes3}
# Out:
# [array([-0.04249584, -0.03969566, -0.0329113 , ...,  0.13641261,
#         0.14148727,  0.14433248])]
# [array([0.08990914, 0.0995031 , 0.10056748, ..., 0.27377167, 0.27561097,
#        0.27585828])]
# [array([-0.39402636, -0.37034911, -0.33925855, ...,  1.01371101,
#         1.03105217,  1.05366994])]

# %%
for key in set_sizes_all:
    s_sizes = set_sizes_all[key]
    #print(s_sizes[0])
    #print(np.shape(s_sizes)[1])
print(z.area(set_sizes_all, np.shape(set_sizes1)[1]))
plt.scatter(sc1_samples[:,0], sc1_samples[:,1])
plt.scatter(sc2_samples[:,0], sc2_samples[:,1])
plt.scatter(sc3_samples[:,0], sc3_samples[:,1])
plt.scatter(ref[0], ref[1])
plt.show()
# Out:
# [1.009331375958604, 0.8655074359479906, 0.7261881048989247]
